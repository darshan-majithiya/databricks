# %%
catalog_name = spark.sql("SELECT current_catalog()").collect()[0][0]
base_volume = f"/Volumes/{catalog_name}/default/fundamentals_demo"

files = ["products.csv"]

for f in files:
    dbutils.fs.cp(f"file:/Workspace/Users/darsh2115@gmail.com/demo/fundamentals/{f}", f"{base_volume}/{f}")

# %%
df = spark.read.load(f"/Volumes/{catalog_name}/default/fundamentals_demo/products.csv", format="csv", header=True)

# %%
df.display()

# %% [markdown]
# # Storing data in Unity Catalog

# %%
delta_table_path = f"/Volumes/{catalog_name}/default/fundamentals_demo/products"
df.write.format("delta").mode("overwrite").save(delta_table_path)

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
SHOW SCHEMAS IN demo;

# %%
# %sql
show tables in demo.default;

# %%
# %sql
show views in demo.default;

# %%
# %sql
show volumes in demo.default;

# %%
# !ls /Volumes/demo/default/fundamentals_demo/products

# %%
from delta.tables import *

# %%
deltaTable = DeltaTable.forPath(spark, delta_table_path)

deltaTable.update(
    condition="ProductID == 772",
    set={"ListPrice": "1000"}
)

# %%
deltaTable.toDF().display()

# %%
new_df = spark.read.format("delta").load(delta_table_path)

# %%
new_df.display()

# %% [markdown]
# # Explore log files

# %%
DeltaTable.forPath(spark, delta_table_path).history().display()

# %%
new_df.write.format("delta").saveAsTable("default.ProductsManaged")
